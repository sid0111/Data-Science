# %%
import pandas as pd

# %%
df = pd.read_csv("data_cleaning_sample.csv")

# %%
df
# Out:
#       Name   Age         City Gender              Email   Join Date
# 0    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 1  Charlie   NaN        Delhi      M    charlie@example  20-07-2021
# 2      Bob  30.0  Los Angeles      M    bob@example.com  15-06-2020
# 3  Charlie   NaN        Delhi      M    charlie@example  20-07-2021
# 4    David  22.0       Mumbai      M  david@example.com  12-11-2019
# 5      NaN  28.0        Delhi      F     eve@domain.com         NaN
# 6    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 7    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 8  Charlie   NaN        Delhi      M    charlie@example  20-07-2021

# %%
df.isnull()
# Out:
#     Name    Age   City  Gender  Email  Join Date
# 0  False  False  False   False  False      False
# 1  False   True  False   False  False      False
# 2  False  False  False   False  False      False
# 3  False   True  False   False  False      False
# 4  False  False  False   False  False      False
# 5   True  False  False   False  False       True
# 6  False  False  False   False  False      False
# 7  False  False  False   False  False      False
# 8  False   True  False   False  False      False

# %%
df.isnull().sum()
# Out:
# Name         1
# Age          3
# City         0
# Gender       0
# Email        0
# Join Date    1
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# Name         0
# Age          0
# City         0
# Gender       0
# Email        0
# Join Date    0
# dtype: int64

# %%
df
# Out:
#     Name   Age         City Gender              Email   Join Date
# 0  Alice  25.0     New York      F  alice@example.com  01-05-2021
# 2    Bob  30.0  Los Angeles      M    bob@example.com  15-06-2020
# 4  David  22.0       Mumbai      M  david@example.com  12-11-2019
# 6  Alice  25.0     New York      F  alice@example.com  01-05-2021
# 7  Alice  25.0     New York      F  alice@example.com  01-05-2021

# %%
df1 = pd.read_csv("data_cleaning_sample.csv")

# %%
df1
# Out:
#       Name   Age         City Gender              Email   Join Date
# 0    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 1  Charlie   NaN        Delhi      M    charlie@example  20-07-2021
# 2      Bob  30.0  Los Angeles      M    bob@example.com  15-06-2020
# 3  Charlie   NaN        Delhi      M    charlie@example  20-07-2021
# 4    David  22.0       Mumbai      M  david@example.com  12-11-2019
# 5      NaN  28.0        Delhi      F     eve@domain.com         NaN
# 6    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 7    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 8  Charlie   NaN        Delhi      M    charlie@example  20-07-2021

# %%
df1["Age"] = df1["Age"].fillna(df1["Age"].mean())

# %%
df1
# Out:
#       Name        Age         City Gender              Email   Join Date
# 0    Alice  25.000000     New York      F  alice@example.com  01-05-2021
# 1  Charlie  25.833333        Delhi      M    charlie@example  20-07-2021
# 2      Bob  30.000000  Los Angeles      M    bob@example.com  15-06-2020
# 3  Charlie  25.833333        Delhi      M    charlie@example  20-07-2021
# 4    David  22.000000       Mumbai      M  david@example.com  12-11-2019
# 5      NaN  28.000000        Delhi      F     eve@domain.com         NaN
# 6    Alice  25.000000     New York      F  alice@example.com  01-05-2021
# 7    Alice  25.000000     New York      F  alice@example.com  01-05-2021
# 8  Charlie  25.833333        Delhi      M    charlie@example  20-07-2021

# %%
df.duplicated()
# Out:
# 0    False
# 2    False
# 4    False
# 6     True
# 7     True
# dtype: bool

# %%
df1["City"].str.contains('delhi', case=False)
# Out:
# 0    False
# 1     True
# 2    False
# 3     True
# 4    False
# 5     True
# 6    False
# 7    False
# 8     True
# Name: City, dtype: bool

# %%
df1['Join Date'].dtypes
# Out:
# dtype('O')

# %%
df1.dtypes
# Out:
# Name          object
# Age          float64
# City          object
# Gender        object
# Email         object
# Join Date     object
# dtype: object

# %%
df1['Join Date'] = pd.to_datetime(df1['Join Date'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 df1['Join Date'] = pd.to_datetime(df1['Join Date'])
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\tools\datetimes.py:1067, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1065         result = arg.map(cache_array)
#    1066     else:
# -> 1067         values = convert_listlike(arg._values, format)
#    1068         result = arg._constructor(values, index=arg.index, name=arg.name)
#    1069 elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\tools\datetimes.py:433, in _convert_listlike_datetimes(arg, format, name, utc, unit, errors, dayfirst, yearfirst, exact)
# ...

# %%
df1['Join Date'] = pd.to_datetime(df1['Join Date'], dayfirst=True)

# %%
df1['Join Date'].astype
# Out:
# <bound method NDFrame.astype of 0   2021-05-01
# 1   2021-07-20
# 2   2020-06-15
# 3   2021-07-20
# 4   2019-11-12
# 5          NaT
# 6   2021-05-01
# 7   2021-05-01
# 8   2021-07-20
# Name: Join Date, dtype: datetime64[ns]>

# %%
df1
# Out:
#       Name        Age         City Gender              Email  Join Date
# 0    Alice  25.000000     New York      F  alice@example.com 2021-05-01
# 1  Charlie  25.833333        Delhi      M    charlie@example 2021-07-20
# 2      Bob  30.000000  Los Angeles      M    bob@example.com 2020-06-15
# 3  Charlie  25.833333        Delhi      M    charlie@example 2021-07-20
# 4    David  22.000000       Mumbai      M  david@example.com 2019-11-12
# 5      NaN  28.000000        Delhi      F     eve@domain.com        NaT
# 6    Alice  25.000000     New York      F  alice@example.com 2021-05-01
# 7    Alice  25.000000     New York      F  alice@example.com 2021-05-01
# 8  Charlie  25.833333        Delhi      M    charlie@example 2021-07-20

# %%
df1['Age Group'] = df1['Age'].apply(lambda x: "Adult" if x>=18 else "Minor")

# %%
df1
# Out:
#       Name        Age         City Gender              Email  Join Date  \
# 0    Alice  25.000000     New York      F  alice@example.com 2021-05-01
# 1  Charlie  25.833333        Delhi      M    charlie@example 2021-07-20
# 2      Bob  30.000000  Los Angeles      M    bob@example.com 2020-06-15
# 3  Charlie  25.833333        Delhi      M    charlie@example 2021-07-20
# 4    David  22.000000       Mumbai      M  david@example.com 2019-11-12
# 5      NaN  28.000000        Delhi      F     eve@domain.com        NaT
# 6    Alice  25.000000     New York      F  alice@example.com 2021-05-01
# 7    Alice  25.000000     New York      F  alice@example.com 2021-05-01
# 8  Charlie  25.833333        Delhi      M    charlie@example 2021-07-20
#
#   Age Group
# 0     Adult
# 1     Adult
# 2     Adult
# 3     Adult
# 4     Adult
# 5     Adult
# 6     Adult
# 7     Adult
# 8     Adult
