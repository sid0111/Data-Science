# %%
pip install sqlalchemy pymysql psycopg2 ipython-sql
# Out:
# Collecting sqlalchemy
#   Downloading sqlalchemy-2.0.41-cp313-cp313-win_amd64.whl.metadata (9.8 kB)
# Collecting pymysql
#   Downloading PyMySQL-1.1.1-py3-none-any.whl.metadata (4.4 kB)
# Collecting psycopg2
#   Downloading psycopg2-2.9.10-cp313-cp313-win_amd64.whl.metadata (4.8 kB)
# Collecting ipython-sql
#   Downloading ipython_sql-0.5.0-py3-none-any.whl.metadata (17 kB)
# Collecting greenlet>=1 (from sqlalchemy)
#   Downloading greenlet-3.2.3-cp313-cp313-win_amd64.whl.metadata (4.2 kB)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\naik siddhesh\appdata\local\programs\python\python313\lib\site-packages (from sqlalchemy) (4.13.2)
# Collecting prettytable (from ipython-sql)
#   Downloading prettytable-3.16.0-py3-none-any.whl.metadata (33 kB)
# Requirement already satisfied: ipython in c:\users\naik siddhesh\appdata\local\programs\python\python313\lib\site-packages (from ipython-sql) (9.3.0)
# Collecting sqlparse (from ipython-sql)
#   Downloading sqlparse-0.5.3-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: six in c:\users\naik siddhesh\appdata\local\programs\python\python313\lib\site-packages (from ipython-sql) (1.17.0)
# Collecting ipython-genutils (from ipython-sql)
#   Downloading ipython_genutils-0.2.0-py2.py3-none-any.whl.metadata (755 bytes)
# Requirement already satisfied: colorama in c:\users\naik siddhesh\appdata\local\programs\python\python313\lib\site-packages (from ipython->ipython-sql) (0.4.6)
# Requirement already satisfied: decorator in c:\users\naik siddhesh\appdata\local\programs\python\python313\lib\site-packages (from ipython->ipython-sql) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in c:\users\naik siddhesh\appdata\local\programs\python\python313\lib\site-packages (from ipython->ipython-sql) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\naik siddhesh\appdata\local\programs\python\python313\lib\site-packages (from ipython->ipython-sql) (0.19.2)
# Requirement already satisfied: matplotlib-inline in c:\users\naik siddhesh\appdata\local\programs\python\python313\lib\site-packages (from ipython->ipython-sql) (0.1.7)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\naik siddhesh\appdata\local\programs\python\python313\lib\site-packages (from ipython->ipython-sql) (3.0.51)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\naik siddhesh\appdata\local\programs\python\python313\lib\site-packages (from ipython->ipython-sql) (2.19.1)
# Requirement already satisfied: stack_data in c:\users\naik siddhesh\appdata\local\programs\python\python313\lib\site-packages (from ipython->ipython-sql) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in c:\users\naik siddhesh\appdata\local\programs\python\python313\lib\site-packages (from ipython->ipython-sql) (5.14.3)
# Requirement already satisfied: wcwidth in c:\users\naik siddhesh\appdata\local\programs\python\python313\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython->ipython-sql) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\naik siddhesh\appdata\local\programs\python\python313\lib\site-packages (from jedi>=0.16->ipython->ipython-sql) (0.8.4)
# Requirement already satisfied: executing>=1.2.0 in c:\users\naik siddhesh\appdata\local\programs\python\python313\lib\site-packages (from stack_data->ipython->ipython-sql) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\naik siddhesh\appdata\local\programs\python\python313\lib\site-packages (from stack_data->ipython->ipython-sql) (3.0.0)
# Requirement already satisfied: pure-eval in c:\users\naik siddhesh\appdata\local\programs\python\python313\lib\site-packages (from stack_data->ipython->ipython-sql) (0.2.3)
# Downloading sqlalchemy-2.0.41-cp313-cp313-win_amd64.whl (2.1 MB)
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    --------- ------------------------------ 0.5/2.1 MB 4.9 MB/s eta 0:00:01
#    ---------------------------------------- 2.1/2.1 MB 9.1 MB/s eta 0:00:00
# Downloading PyMySQL-1.1.1-py3-none-any.whl (44 kB)
# Downloading psycopg2-2.9.10-cp313-cp313-win_amd64.whl (2.6 MB)
#    ---------------------------------------- 0.0/2.6 MB ? eta -:--:--
#    ---------------------------------------- 2.6/2.6 MB 14.9 MB/s eta 0:00:00
# Downloading ipython_sql-0.5.0-py3-none-any.whl (20 kB)
# Downloading greenlet-3.2.3-cp313-cp313-win_amd64.whl (297 kB)
# Downloading ipython_genutils-0.2.0-py2.py3-none-any.whl (26 kB)
# Downloading prettytable-3.16.0-py3-none-any.whl (33 kB)
# Downloading sqlparse-0.5.3-py3-none-any.whl (44 kB)
# Installing collected packages: ipython-genutils, sqlparse, pymysql, psycopg2, prettytable, greenlet, sqlalchemy, ipython-sql
#
#    ----- ---------------------------------- 1/8 [sqlparse]
#    ----- ---------------------------------- 1/8 [sqlparse]
#    ---------- ----------------------------- 2/8 [pymysql]
#    ---------- ----------------------------- 2/8 [pymysql]
#    --------------- ------------------------ 3/8 [psycopg2]
#    ------------------------- -------------- 5/8 [greenlet]
#    ------------------------- -------------- 5/8 [greenlet]
#    ------------------------------ --------- 6/8 [sqlalchemy]
#    ------------------------------ --------- 6/8 [sqlalchemy]
#    ------------------------------ --------- 6/8 [sqlalchemy]
#    ------------------------------ --------- 6/8 [sqlalchemy]
#    ------------------------------ --------- 6/8 [sqlalchemy]
#    ------------------------------ --------- 6/8 [sqlalchemy]
#    ------------------------------ --------- 6/8 [sqlalchemy]
#    ------------------------------ --------- 6/8 [sqlalchemy]
#    ------------------------------ --------- 6/8 [sqlalchemy]
#    ------------------------------ --------- 6/8 [sqlalchemy]
#    ------------------------------ --------- 6/8 [sqlalchemy]
#    ------------------------------ --------- 6/8 [sqlalchemy]
#    ------------------------------ --------- 6/8 [sqlalchemy]
#    ------------------------------ --------- 6/8 [sqlalchemy]
#    ------------------------------ --------- 6/8 [sqlalchemy]
#    ------------------------------ --------- 6/8 [sqlalchemy]
#    ------------------------------ --------- 6/8 [sqlalchemy]
#    ------------------------------ --------- 6/8 [sqlalchemy]
#    ------------------------------ --------- 6/8 [sqlalchemy]
#    ------------------------------ --------- 6/8 [sqlalchemy]
#    ------------------------------ --------- 6/8 [sqlalchemy]
#    ------------------------------ --------- 6/8 [sqlalchemy]
#    ------------------------------ --------- 6/8 [sqlalchemy]
#    ----------------------------------- ---- 7/8 [ipython-sql]
#    ---------------------------------------- 8/8 [ipython-sql]
#
# Successfully installed greenlet-3.2.3 ipython-genutils-0.2.0 ipython-sql-0.5.0 prettytable-3.16.0 psycopg2-2.9.10 pymysql-1.1.1 sqlalchemy-2.0.41 sqlparse-0.5.3
# Note: you may need to restart the kernel to use updated packages.

# %%
from sqlalchemy import create_engine

# %%
import pandas as pd

# %%
username = 'root'
password = 'password'  
host = 'localhost'
port = 3306
database = 'sid'

# %%
connection_string = f"mysql+pymysql://{username}:{password}@{host}:{port}/{database}"

# %%
engine = create_engine(connection_string)

df = pd.read_sql("SELECT * FROM emp", engine)

df
# Out:
#     ID             NAME  AGE GENDER                       EMAIL
# 0   31       Naik Samar   10      M        naiksam110@gmail.com
# 1   33       Naik Sanvi   14      F          naiksav2@gmail.com
# 2   34     Bankar Arnav   18      M            arnavb@gmail.com
# 3   35   Bankar Abhinav   16      M        bankarabhi@gmail.com
# 4   36       Patil Riya   19      F      riya.patil03@gmail.com
# 5   37   Kulkarni Anaya   20      F  anaya.kulkarni02@gmail.com
# 6   38   Deshmukh Aarav   22      M        aaravd2023@gmail.com
# 7   39     Joshi Nikhil   23      M     nikhiljoshi19@gmail.com
# 8   40     Shinde Meera   15      F     meerashinde45@gmail.com
# 9   41      Gadre Tanvi   17      F       tanvi.gadre@gmail.com
# 10  42       Kale Omkar   24      M       omkarkale98@gmail.com
# 11  43       More Sneha   16      F       snehamore66@gmail.com
# 12  44   Gokhale Ishaan   13      M  ishaan.gokhale12@gmail.com
# 13  45     Nikam Vedika   25      F     vedikanikam09@gmail.com
# 14  46       Pawar Yash   19      M       yashpawar22@gmail.com
# 15  47    Jadhav Pranav   21      M           pranavj@gmail.com
# 16  48     Phadke Kavya   22      F    kavya.phadke33@gmail.com
# 17  49      Thakur Aman   20      M      amanthakur78@gmail.com
# 18  50      Sawant Diya   14      F        diyasawant@gmail.com
# 19  51     Kamble Rohit   26      M      rohit.kamble@gmail.com
# 20  52   Bhosale Rutuja   18      F      rutu.bhosale@gmail.com
# 21  53      Yadav Karan   17      M      karanyadav45@gmail.com
# 22  54      Shirke Isha   15      F       isha.shirke@gmail.com
# 23  55       Rane Tejas   19      M       tejasrane91@gmail.com
# 24  56      Dixit Aanya   16      F     aanyadixit123@gmail.com
# 25  57  Lokhande Neeraj   23      M         neerajlok@gmail.com
# 26  58   Nerurkar Priya   21      F      priyaneru321@gmail.com
# 27  59    Inamdar Sohan   18      M        sohan.inam@gmail.com
# 28  60   Pathak Radhika   20      F     radhikapathak@gmail.com
